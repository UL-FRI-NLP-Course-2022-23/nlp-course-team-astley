# %%
import re
import spacy
import nltk
from nltk.tokenize import sent_tokenize
from transformers import pipeline, DistilBertTokenizer, DistilBertForSequenceClassification
import torch
from concurrent.futures import ThreadPoolExecutor, as_completed

# Download the NLTK package required for sentence tokenization
nltk.download('punkt')

class SentimentAnalysis:
    def __init__(self):
        # Load the pre-trained SpaCy model
        self.nlp = spacy.load("en_core_web_trf")
        self.model_path = './sentiment_model'
        self.tokenizer = DistilBertTokenizer.from_pretrained(self.model_path, local_files_only=True)
        self.model = DistilBertForSequenceClassification.from_pretrained(self.model_path, num_labels=2)

    def detect_characters(self, story):
        doc = self.nlp(story)
        characters = set()

        for ent in doc.ents:
            if ent.label_ == "PERSON":
                characters.add(ent.text)

        return list(characters)

    def extract_character_sentences(self, story, characters):
        sentences = sent_tokenize(story)
        character_sentences = {}

        for i, sentence in enumerate(sentences):
            for name in characters:
                if re.search(r'\b' + re.escape(name) + r'\b', sentence, re.IGNORECASE):
                    if name not in character_sentences:
                        character_sentences[name] = []
                    character_sentences[name].append(sentence)

        return character_sentences

    def fine_tuned_sentiment_analysis(self, character_sentences, max_length=512):
        character_sentiments = {}

        for name, contexts in character_sentences.items():
            if contexts:
                weighted_scores = []
                weight = 1
                for context in contexts:
                    inputs = self.tokenizer(context, padding=True, truncation=True, return_tensors='pt')
                    with torch.no_grad():
                        outputs = self.model(**inputs)
                        logits = outputs.logits

                    predicted_label = torch.argmax(logits, dim=1).item() * weight
                    compound_score = "positive" if predicted_label >= 0.5 else "negative"
                    weighted_scores.append(compound_score)
                if weighted_scores.count("positive") > weighted_scores.count("negative"):
                    character_sentiments[name] = "positive"
                else:
                    character_sentiments[name] = "negative"

        return character_sentiments

# %%
import csv
import json

with open('non_names_characters.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter='\n')
    non_names = [row[0].lower() for row in reader]


def process_story(i, row, sentiment):
    story = ' '.join(row)
    characters = sentiment.detect_characters(story)
    if not characters:
        characters = non_names
    character_sentences = sentiment.extract_character_sentences(story, characters)
    character_sentiments = sentiment.fine_tuned_sentiment_analysis(character_sentences)

    characters_info = {}
    characters_info["story_id"] = i + 52665
    characters_info["characters"] = {name: sentiment for name, sentiment in character_sentiments.items()}
    print(characters_info)
    return characters_info


sentiment = SentimentAnalysis()
with open('val_reformatted.csv', 'r') as csvfile:
    reader = csv.reader(csvfile, delimiter=',')
    header = next(reader)

    with ThreadPoolExecutor() as executor:
        futures = {executor.submit(process_story, i, row, sentiment) for i, row in enumerate(reader)}
        stories = [future.result() for future in as_completed(futures)]

with open("val_dataset.json", "w") as outfile:
    json.dump(stories, outfile, indent=4)
# Out:
# {'story_id': 28687, 'characters': {'Rocky': 'positive'}}
# {'story_id': 28695, 'characters': {'Sarah': 'positive'}}
# {'story_id': 28689, 'characters': {'Jessica': 'positive'}}
# {'story_id': 28682, 'characters': {'Jason': 'negative'}}
# {'story_id': 28674, 'characters': {'Sarah': 'positive', 'Mike': 'positive'}}
# {'story_id': 28692, 'characters': {'Chris': 'negative'}}
# {'story_id': 28691, 'characters': {'John': 'positive'}}
# {'story_id': 28686, 'characters': {'Jeremy': 'positive', 'Jim': 'negative'}}
# {'story_id': 28694, 'characters': {'Sarah': 'positive'}}
# {'story_id': 28688, 'characters': {'Abdul': 'positive'}}
# {'story_id': 28705, 'characters': {'Henry': 'positive'}}
# {'story_id': 28693, 'characters': {'i': 'positive', 'boyfriend': 'positive'}}
# {'story_id': 28703, 'characters': {'Justin': 'positive'}}
# {'story_id': 28696, 'characters': {'Mike': 'negative'}}
# {'story_id': 52676, 'characters': {'Danny': 'positive'}}
# {'story_id': 28699, 'characters': {'Richard': 'positive'}}
# {'story_id': 28697, 'characters': {'Colin': 'positive'}}
# {'story_id': 28698, 'characters': {'James': 'negative'}}
# {'story_id': 28700, 'characters': {'Missy': 'positive'}}
# {'story_id': 28701, 'characters': {'David': 'negative'}}
# {'story_id': 28704, 'characters': {'Paula': 'negative'}}
# {'story_id': 28702, 'characters': {'Johnson': 'positive'}}
# {'story_id': 52673, 'characters': {'Trish': 'negative'}}
# {'story_id': 52680, 'characters': {'Tiffany': 'negative'}}
# {'story_id': 52666, 'characters': {'Sarah': 'positive'}}
# {'story_id': 52668, 'characters': {'i': 'negative'}}
# {'story_id': 28710, 'characters': {}}
# {'story_id': 52678, 'characters': {'Ellen': 'positive'}}
# {'story_id': 28706, 'characters': {}}
# {'story_id': 52679, 'characters': {'Jesse': 'positive'}}
# {'story_id': 52674, 'characters': {'Tony': 'positive'}}
# {'story_id': 52672, 'characters': {'Caroline': 'negative'}}
# {'story_id': 28711, 'characters': {'Lindsey': 'positive'}}
# {'story_id': 52671, 'characters': {'Billy': 'positive', 'John': 'positive'}}
# {'story_id': 52669, 'characters': {'Jim': 'positive'}}
# {'story_id': 52670, 'characters': {'Ron': 'positive'}}
# {'story_id': 52667, 'characters': {'Gina': 'positive'}}
# {'story_id': 52675, 'characters': {'Ignacio': 'positive'}}
# {'story_id': 52665, 'characters': {'Laverne': 'positive'}}
# {'story_id': 28720, 'characters': {'Bob': 'positive'}}
# {'story_id': 28709, 'characters': {'Troy': 'positive'}}
# {'story_id': 28707, 'characters': {'Sandy': 'positive'}}
# {'story_id': 28708, 'characters': {'Jon': 'positive'}}
# {'story_id': 52681, 'characters': {'Gina': 'negative'}}
# {'story_id': 28717, 'characters': {'Angel': 'negative'}}
# {'story_id': 28716, 'characters': {'June': 'positive'}}
# {'story_id': 52688, 'characters': {'Sam': 'positive'}}
# {'story_id': 28715, 'characters': {'Dan': 'positive'}}
# {'story_id': 28712, 'characters': {'Jeff': 'negative'}}
# {'story_id': 52677, 'characters': {'Mary': 'positive'}}
# {'story_id': 52689, 'characters': {'Larry': 'positive'}}
# {'story_id': 28713, 'characters': {'Michael': 'positive'}}
# {'story_id': 28718, 'characters': {'Sydney': 'negative'}}
# {'story_id': 52684, 'characters': {'Nya': 'positive'}}
# {'story_id': 28714, 'characters': {'Sue': 'positive', 'Kate': 'positive'}}
# {'story_id': 52682, 'characters': {'Alice': 'negative'}}
# {'story_id': 52685, 'characters': {'Javier': 'positive'}}
# {'story_id': 28721, 'characters': {'Jen': 'negative'}}
# {'story_id': 28723, 'characters': {'Tanja': 'positive'}}
# {'story_id': 28729, 'characters': {'Jack': 'positive'}}
# {'story_id': 52687, 'characters': {'Ron': 'positive'}}
# {'story_id': 28727, 'characters': {'father': 'positive'}}
# {'story_id': 52683, 'characters': {'Ted': 'positive'}}
# {'story_id': 52686, 'characters': {'Rachel': 'positive'}}
# {'story_id': 52691, 'characters': {'Sammy': 'positive'}}
# {'story_id': 28719, 'characters': {'i': 'negative'}}
# {'story_id': 52692, 'characters': {'Jared': 'positive'}}
# {'story_id': 52695, 'characters': {'Lina': 'positive'}}
# {'story_id': 52690, 'characters': {'i': 'negative', 'boyfriend': 'positive', 'girlfriend': 'positive'}}
# {'story_id': 28736, 'characters': {}}
# {'story_id': 52700, 'characters': {'Jim': 'positive'}}
# {'story_id': 28728, 'characters': {'Sven': 'positive'}}
# {'story_id': 52694, 'characters': {'Aliza': 'negative'}}
# {'story_id': 52693, 'characters': {'Joe': 'positive'}}
# {'story_id': 28726, 'characters': {'Marianne': 'negative'}}
# {'story_id': 28722, 'characters': {'Abby': 'positive', 'Carl': 'positive'}}
# {'story_id': 28730, 'characters': {'Tom': 'negative'}}
# {'story_id': 28732, 'characters': {'Blair': 'positive'}}
# {'story_id': 52697, 'characters': {'Bev': 'negative'}}
# {'story_id': 28738, 'characters': {'Tom': 'positive'}}
# {'story_id': 28725, 'characters': {'Kies': 'negative'}}
# {'story_id': 52698, 'characters': {"Frank Pepe's": 'positive'}}
# {'story_id': 28724, 'characters': {'Jim': 'positive'}}
# {'story_id': 28742, 'characters': {'Mary': 'positive'}}
# {'story_id': 28731, 'characters': {'Sally': 'positive'}}
# {'story_id': 52696, 'characters': {'i': 'positive'}}
# {'story_id': 28737, 'characters': {'Allie': 'negative'}}
# {'story_id': 28733, 'characters': {'Jerry': 'positive'}}
# {'story_id': 52703, 'characters': {'Anna': 'positive'}}
# {'story_id': 28740, 'characters': {'Tim': 'positive'}}
# {'story_id': 52701, 'characters': {'Randy': 'positive'}}
# {'story_id': 52702, 'characters': {'brother': 'negative', 'i': 'negative'}}
# {'story_id': 28735, 'characters': {'Ricky': 'positive'}}
# {'story_id': 28741, 'characters': {'Sammy': 'positive'}}
# {'story_id': 52707, 'characters': {'Priya': 'positive'}}
# {'story_id': 52708, 'characters': {'Karen': 'positive'}}
# {'story_id': 28739, 'characters': {'i': 'positive'}}
# {'story_id': 52706, 'characters': {'Joe': 'positive'}}
# {'story_id': 52704, 'characters': {'Sarah': 'positive', 'David': 'positive'}}
# {'story_id': 52710, 'characters': {'Donald': 'negative'}}
# {'story_id': 52699, 'characters': {'Bernice': 'positive'}}
# {'story_id': 28752, 'characters': {'Tim': 'positive'}}
# {'story_id': 28746, 'characters': {'Shane': 'positive'}}
# {'story_id': 28745, 'characters': {'Sassy': 'positive'}}
# {'story_id': 52711, 'characters': {'Angela': 'positive', 'Eddie': 'positive'}}
# {'story_id': 52712, 'characters': {'Rachel': 'positive'}}
# {'story_id': 52709, 'characters': {'i': 'negative'}}
# {'story_id': 28743, 'characters': {'grandparent': 'positive'}}
# {'story_id': 52716, 'characters': {'Boris': 'negative'}}
# {'story_id': 28744, 'characters': {'Amy': 'negative'}}
# {'story_id': 52705, 'characters': {'AJ': 'positive', 'Aj': 'positive'}}
# {'story_id': 28747, 'characters': {'Kim': 'positive'}}
# {'story_id': 52713, 'characters': {'Jim': 'positive'}}
# {'story_id': 28748, 'characters': {'Luis': 'negative'}}
# {'story_id': 28734, 'characters': {'Ali': 'positive', 'Dave': 'positive', 'Keith': 'positive'}}
# {'story_id': 28750, 'characters': {'Billy': 'positive'}}
# {'story_id': 52715, 'characters': {'David': 'negative'}}
# {'story_id': 28754, 'characters': {'Tom': 'negative'}}
# {'story_id': 28755, 'characters': {'Sara': 'positive'}}
# {'story_id': 28749, 'characters': {'i': 'positive'}}
# {'story_id': 28762, 'characters': {'Susie': 'positive'}}
# {'story_id': 52714, 'characters': {'i': 'positive', 'doctor': 'positive'}}
# {'story_id': 52721, 'characters': {'i': 'positive'}}
# {'story_id': 52719, 'characters': {'Gary': 'positive'}}
# {'story_id': 52717, 'characters': {'police officer': 'positive'}}
# {'story_id': 52720, 'characters': {'Timmy': 'negative'}}
# {'story_id': 28751, 'characters': {'Jan': 'positive'}}
# {'story_id': 52729, 'characters': {'Bobby': 'positive'}}
# {'story_id': 52724, 'characters': {'Jason': 'negative'}}
# {'story_id': 28756, 'characters': {'Tom': 'negative'}}
# {'story_id': 52722, 'characters': {'Amber': 'negative'}}
# {'story_id': 28753, 'characters': {'Olivia': 'positive'}}
# {'story_id': 28766, 'characters': {'Rita': 'positive'}}
# {'story_id': 28759, 'characters': {'Jim': 'positive'}}
# {'story_id': 52723, 'characters': {'Eve': 'positive'}}
# {'story_id': 28760, 'characters': {'Maryann': 'positive', 'Josh': 'positive'}}
# {'story_id': 52727, 'characters': {'Megan': 'negative'}}
# {'story_id': 52728, 'characters': {'Tyler': 'negative'}}
# {'story_id': 28761, 'characters': {'Judy': 'negative'}}
# {'story_id': 52726, 'characters': {'Sara': 'positive'}}
# {'story_id': 52730, 'characters': {}}
# {'story_id': 28763, 'characters': {'Joe': 'positive'}}
# {'story_id': 28757, 'characters': {'Sherri': 'positive'}}
# {'story_id': 52725, 'characters': {'Linda': 'positive'}}
# {'story_id': 52735, 'characters': {'Ellen': 'negative', 'Elly': 'positive'}}
# {'story_id': 52734, 'characters': {'Pam': 'positive'}}
# {'story_id': 28764, 'characters': {'Tim': 'positive'}}
# {'story_id': 28773, 'characters': {'Jane': 'positive'}}
# {'story_id': 28765, 'characters': {'Tim': 'negative'}}
# {'story_id': 52731, 'characters': {'mother': 'positive'}}
# {'story_id': 28770, 'characters': {'i': 'positive'}}
# {'story_id': 28758, 'characters': {'i': 'negative'}}
# {'story_id': 28767, 'characters': {'Cat': 'positive'}}
# {'story_id': 52737, 'characters': {'Tim': 'positive'}}
# {'story_id': 52732, 'characters': {'Timmy': 'positive'}}
# {'story_id': 52718, 'characters': {'nathan': 'negative', 'Nathan': 'negative'}}
# {'story_id': 28769, 'characters': {'i': 'negative'}}
# {'story_id': 28775, 'characters': {'Cassie': 'positive'}}
# {'story_id': 52733, 'characters': {'daughter': 'positive'}}
# {'story_id': 52739, 'characters': {'Holly': 'positive'}}
# {'story_id': 52742, 'characters': {'Sean': 'positive'}}
# {'story_id': 52736, 'characters': {'Jim': 'positive'}}
# {'story_id': 28771, 'characters': {'Bernie': 'positive'}}
# {'story_id': 28787, 'characters': {}}
# {'story_id': 52744, 'characters': {'John': 'negative'}}
# {'story_id': 28779, 'characters': {'Helen': 'positive'}}
# {'story_id': 28786, 'characters': {'Scott': 'positive'}}
# {'story_id': 28777, 'characters': {'Cindy': 'negative'}}
# {'story_id': 52740, 'characters': {'Jill': 'negative'}}
# {'story_id': 52738, 'characters': {'son': 'positive', 'i': 'positive'}}
# {'story_id': 28768, 'characters': {'pats': 'negative', 'Pat': 'negative'}}
# {'story_id': 28782, 'characters': {'Shauna': 'positive'}}
# {'story_id': 28772, 'characters': {'Shad': 'positive'}}
# {'story_id': 52745, 'characters': {'Gina': 'negative'}}
# {'story_id': 28774, 'characters': {'Candy': 'positive'}}
# {'story_id': 52747, 'characters': {'Tyler': 'positive'}}
# {'story_id': 52748, 'characters': {'Jimmy': 'positive'}}
# {'story_id': 28776, 'characters': {'Tim': 'positive', 'Fred': 'positive'}}
# {'story_id': 28780, 'characters': {'David': 'positive'}}
# {'story_id': 52741, 'characters': {'Addie': 'negative'}}
# {'story_id': 52755, 'characters': {'Neil': 'positive'}}
# {'story_id': 28778, 'characters': {'Allie': 'positive'}}
# {'story_id': 28791, 'characters': {'Ron': 'positive'}}
# {'story_id': 52746, 'characters': {'Kaya': 'positive'}}
# {'story_id': 28783, 'characters': {'Noah': 'positive'}}
# {'story_id': 28784, 'characters': {'Kate': 'positive'}}
# {'story_id': 52750, 'characters': {'Ryan': 'positive'}}
# {'story_id': 52753, 'characters': {'i': 'positive'}}
# {'story_id': 28785, 'characters': {'i': 'positive'}}
# {'story_id': 28789, 'characters': {}}
# {'story_id': 28795, 'characters': {'Kelly': 'positive'}}
# {'story_id': 52749, 'characters': {'Maxine': 'negative'}}
# {'story_id': 52752, 'characters': {'Nick': 'positive'}}
# {'story_id': 52743, 'characters': {'Sam': 'positive', 'Fred': 'positive'}}
# {'story_id': 52751, 'characters': {'i': 'positive'}}
# {'story_id': 28781, 'characters': {'Karyn': 'positive', 'Brian': 'positive'}}
# {'story_id': 52764, 'characters': {'Neil': 'positive'}}
# {'story_id': 28793, 'characters': {'Ana': 'positive'}}
# {'story_id': 52756, 'characters': {'Mary': 'negative'}}
# {'story_id': 28801, 'characters': {'Tim': 'positive'}}
# {'story_id': 28805, 'characters': {'Susie': 'positive'}}
# {'story_id': 28790, 'characters': {'Elaine': 'positive'}}
# {'story_id': 28796, 'characters': {'Susie': 'positive'}}
# {'story_id': 52758, 'characters': {'Colin': 'negative'}}
# {'story_id': 52754, 'characters': {'Michelle': 'negative'}}
# {'story_id': 52761, 'characters': {'Amy': 'positive'}}
# {'story_id': 28788, 'characters': {'Hank': 'negative'}}
# {'story_id': 52757, 'characters': {'Scott': 'positive'}}
# {'story_id': 52760, 'characters': {'Fred': 'positive'}}
# {'story_id': 28806, 'characters': {'Jill': 'positive'}}
# {'story_id': 52759, 'characters': {'Jordan': 'positive'}}
# {'story_id': 28800, 'characters': {'Renee': 'positive'}}
# {'story_id': 28794, 'characters': {'i': 'positive'}}
# {'story_id': 52767, 'characters': {}}
# {'story_id': 28799, 'characters': {'Joe': 'positive'}}
# {'story_id': 28809, 'characters': {'Dennis': 'positive', 'Dennish': 'positive'}}
# {'story_id': 52765, 'characters': {'Cam': 'positive'}}
# {'story_id': 28797, 'characters': {'Pat': 'positive'}}
# {'story_id': 28802, 'characters': {'Mona': 'positive'}}
# {'story_id': 28792, 'characters': {'John': 'positive'}}
# {'story_id': 52763, 'characters': {'David': 'positive'}}
# {'story_id': 52771, 'characters': {'Leah': 'positive'}}
# {'story_id': 52768, 'characters': {'Dick': 'positive', 'Tom': 'negative'}}
# {'story_id': 28798, 'characters': {'Amy': 'negative'}}
# {'story_id': 52772, 'characters': {'Ava': 'negative'}}
# {'story_id': 28807, 'characters': {'Nicole': 'positive'}}
# {'story_id': 52769, 'characters': {'Harry': 'positive'}}
# {'story_id': 52762, 'characters': {'Ellen': 'positive', 'Tim': 'negative'}}
# {'story_id': 52777, 'characters': {'Paul': 'positive'}}
# {'story_id': 28815, 'characters': {'Allie': 'negative'}}
# {'story_id': 52766, 'characters': {'Rosie': 'positive'}}
# {'story_id': 28816, 'characters': {'Suzy': 'negative'}}
# {'story_id': 28812, 'characters': {'Susie': 'positive'}}
# {'story_id': 28804, 'characters': {'Grace': 'positive'}}
# {'story_id': 52774, 'characters': {'Jasper': 'negative'}}
# {'story_id': 52775, 'characters': {'i': 'positive'}}
# {'story_id': 28822, 'characters': {'Steph': 'positive'}}
# {'story_id': 28811, 'characters': {'Marty': 'positive'}}
# {'story_id': 28808, 'characters': {'Tommy': 'negative', 'Sally': 'negative'}}
# {'story_id': 52770, 'characters': {'i': 'positive', 'teacher': 'negative'}}
# {'story_id': 52780, 'characters': {}}
# {'story_id': 52783, 'characters': {'Gina': 'positive'}}
# {'story_id': 28803, 'characters': {'Tony': 'negative', 'Beethoven': 'positive', 'Bach': 'positive'}}
# {'story_id': 52773, 'characters': {'Harry': 'positive'}}
# {'story_id': 28813, 'characters': {'Aaron': 'positive'}}
# {'story_id': 52786, 'characters': {'John': 'negative'}}
# {'story_id': 28810, 'characters': {'Ryan': 'positive'}}
# {'story_id': 28817, 'characters': {'Derek': 'negative'}}
# {'story_id': 52776, 'characters': {'Tom': 'positive'}}
# {'story_id': 28814, 'characters': {'Jan': 'positive', 'Jared': 'positive'}}
# {'story_id': 28826, 'characters': {}}
# {'story_id': 28828, 'characters': {'Tim': 'positive'}}
# {'story_id': 52778, 'characters': {'Harvey': 'positive'}}
# {'story_id': 28819, 'characters': {'Joe': 'negative'}}
# {'story_id': 52784, 'characters': {'Alan': 'negative'}}
# {'story_id': 28832, 'characters': {'Tom': 'positive'}}
# {'story_id': 52782, 'characters': {'i': 'positive'}}
# {'story_id': 52781, 'characters': {'Gina': 'negative'}}
# {'story_id': 28821, 'characters': {'Suzy': 'positive'}}
# {'story_id': 52785, 'characters': {'Jay': 'positive'}}
# {'story_id': 28831, 'characters': {}}
# {'story_id': 28830, 'characters': {'Candace': 'positive'}}
# {'story_id': 52787, 'characters': {'Kev': 'positive'}}
# {'story_id': 52790, 'characters': {'i': 'negative'}}
# {'story_id': 28818, 'characters': {'Emma': 'positive', 'Allie': 'positive'}}
# {'story_id': 52789, 'characters': {'Lina': 'positive'}}
# {'story_id': 28825, 'characters': {'Tom': 'negative'}}
# {'story_id': 28824, 'characters': {'Mallory': 'positive'}}
# {'story_id': 28823, 'characters': {'Tim': 'positive'}}
# {'story_id': 52791, 'characters': {'Andy': 'positive'}}
# {'story_id': 28820, 'characters': {'Sue': 'positive', 'Steve': 'positive'}}
# {'story_id': 28836, 'characters': {'Tim': 'positive'}}
# {'story_id': 28827, 'characters': {'Robert': 'negative'}}
# {'story_id': 52779, 'characters': {'i': 'positive'}}
# {'story_id': 52793, 'characters': {'Gina': 'positive'}}
# {'story_id': 52795, 'characters': {'Frank': 'positive'}}
# {'story_id': 52794, 'characters': {'Vivienne': 'positive'}}
# {'story_id': 52788, 'characters': {'Emily': 'positive'}}
# {'story_id': 28833, 'characters': {'Terry': 'positive'}}
# {'story_id': 28841, 'characters': {'Suzy': 'positive'}}
# {'story_id': 52803, 'characters': {'John': 'positive'}}
# {'story_id': 28834, 'characters': {'Julie': 'positive'}}
# {'story_id': 28840, 'characters': {'John': 'positive'}}
# {'story_id': 52799, 'characters': {'Reg': 'positive'}}
# {'story_id': 28835, 'characters': {'Marta': 'negative'}}
# {'story_id': 52796, 'characters': {'Gina': 'positive'}}
# {'story_id': 28838, 'characters': {'Julie': 'positive'}}
# {'story_id': 52798, 'characters': {'Ben': 'positive'}}
# {'story_id': 52806, 'characters': {'i': 'positive'}}
# {'story_id': 28829, 'characters': {'friend': 'positive', 'i': 'positive'}}
# {'story_id': 52800, 'characters': {'Caroline': 'positive'}}
# {'story_id': 52797, 'characters': {'John': 'positive'}}
# {'story_id': 52792, 'characters': {'Donna': 'positive', 'Ty': 'positive'}}
# {'story_id': 28844, 'characters': {}}
# {'story_id': 28845, 'characters': {'Tina': 'positive'}}
# {'story_id': 52802, 'characters': {'Bob': 'positive'}}
# {'story_id': 28843, 'characters': {'Joan': 'negative'}}
# {'story_id': 52804, 'characters': {'Neil': 'positive'}}
# {'story_id': 28842, 'characters': {'Michael': 'negative'}}
# {'story_id': 28839, 'characters': {'Matt': 'positive'}}
# {'story_id': 52808, 'characters': {'Sal': 'positive'}}
# {'story_id': 28846, 'characters': {'Mark': 'positive'}}
# {'story_id': 28852, 'characters': {'i': 'positive'}}
# {'story_id': 28851, 'characters': {}}
# {'story_id': 52805, 'characters': {'John': 'positive'}}
# {'story_id': 28849, 'characters': {'Lucy': 'positive'}}
# {'story_id': 52801, 'characters': {'Cindy': 'positive', 'Tom': 'positive'}}
# {'story_id': 28837, 'characters': {'teacher': 'negative', 'i': 'positive'}}
# {'story_id': 52807, 'characters': {'Alex': 'positive'}}
# {'story_id': 52809, 'characters': {'Javier': 'positive'}}
# {'story_id': 28848, 'characters': {'Jen': 'negative'}}
# {'story_id': 28850, 'characters': {'Mike': 'positive'}}
# {'story_id': 52810, 'characters': {'Gordon': 'positive'}}
# {'story_id': 52814, 'characters': {}}
# {'story_id': 52812, 'characters': {'mother': 'positive'}}
# {'story_id': 52813, 'characters': {'Sarah': 'negative'}}
# {'story_id': 52811, 'characters': {'Mim': 'negative'}}
# {'story_id': 52820, 'characters': {'Joe': 'positive'}}
# {'story_id': 28853, 'characters': {'Alex': 'positive'}}
# {'story_id': 52815, 'characters': {'Tim': 'positive'}}
# {'story_id': 28861, 'characters': {'Allie': 'negative'}}
# {'story_id': 28855, 'characters': {'daughter': 'positive', 'i': 'positive'}}
# {'story_id': 28867, 'characters': {}}
# {'story_id': 28864, 'characters': {'Tina': 'positive', 'Fred': 'positive'}}
# {'story_id': 52816, 'characters': {'Frankie': 'negative'}}
# {'story_id': 28857, 'characters': {'Tom': 'negative'}}
# {'story_id': 52818, 'characters': {'George': 'positive'}}
# {'story_id': 52827, 'characters': {'Lia': 'negative'}}
# {'story_id': 28856, 'characters': {'Janet': 'positive'}}
# {'story_id': 28847, 'characters': {'Sue': 'positive', 'Kate': 'positive'}}
# {'story_id': 52817, 'characters': {'Nancy': 'negative', 'Ian': 'negative'}}
# {'story_id': 28859, 'characters': {'i': 'positive'}}
# {'story_id': 52819, 'characters': {'Kevin': 'positive'}}
# {'story_id': 28854, 'characters': {'Todd': 'positive'}}
# {'story_id': 52822, 'characters': {'John': 'positive'}}
# {'story_id': 28860, 'characters': {'i': 'positive'}}
# {'story_id': 52824, 'characters': {'daughter': 'positive'}}
# {'story_id': 52826, 'characters': {'Sandy': 'positive', 'Louie': 'positive'}}
# {'story_id': 28873, 'characters': {'Jane': 'positive'}}
# {'story_id': 52825, 'characters': {'i': 'negative'}}
# {'story_id': 52821, 'characters': {'Sven': 'positive'}}
# {'story_id': 28875, 'characters': {'Jimmy': 'positive'}}
# {'story_id': 28868, 'characters': {'president': 'positive'}}
# {'story_id': 52837, 'characters': {'Lou': 'positive'}}
# {'story_id': 52823, 'characters': {'Matt': 'positive'}}
# {'story_id': 28866, 'characters': {'i': 'positive'}}
# {'story_id': 52833, 'characters': {'i': 'positive'}}
# {'story_id': 28871, 'characters': {'Jerry': 'positive'}}
# {'story_id': 52832, 'characters': {'Jane': 'positive'}}
# {'story_id': 28862, 'characters': {'Charles': 'positive'}}
# {'story_id': 52830, 'characters': {'Gina': 'positive'}}
# {'story_id': 28865, 'characters': {'Gary': 'positive'}}
# {'story_id': 52828, 'characters': {'i': 'positive'}}
# {'story_id': 52831, 'characters': {'Pamela': 'positive'}}
# {'story_id': 28872, 'characters': {'Justin': 'positive'}}
# {'story_id': 52829, 'characters': {'Gina': 'positive'}}
# {'story_id': 28881, 'characters': {'Allie': 'positive'}}
# {'story_id': 28858, 'characters': {'Smith': 'positive', 'Zoey': 'negative', 'Zoe': 'positive'}}
# {'story_id': 28870, 'characters': {'i': 'negative'}}
# {'story_id': 28869, 'characters': {'Stewart': 'negative'}}
# {'story_id': 52836, 'characters': {'i': 'positive'}}
# {'story_id': 28876, 'characters': {'Tricia': 'negative'}}
# {'story_id': 52835, 'characters': {'i': 'positive'}}
# {'story_id': 28874, 'characters': {'Shelly': 'positive'}}
# {'story_id': 28877, 'characters': {'Troy': 'positive'}}
# {'story_id': 28863, 'characters': {'Marie': 'positive', 'Colleen': 'positive', 'Nina': 'positive'}}
# {'story_id': 28878, 'characters': {'Greg': 'positive'}}
# {'story_id': 52842, 'characters': {'Juanita': 'positive'}}
# {'story_id': 28882, 'characters': {}}
# {'story_id': 52834, 'characters': {'Fred': 'positive', 'Frank': 'positive'}}
# {'story_id': 52840, 'characters': {'Sara': 'positive'}}
# {'story_id': 52838, 'characters': {'Betsy': 'negative'}}
# {'story_id': 28889, 'characters': {'John': 'positive'}}
# {'story_id': 52839, 'characters': {'Joy': 'positive'}}
# {'story_id': 52849, 'characters': {'Sal': 'negative'}}
# {'story_id': 28880, 'characters': {'Joanna': 'positive'}}
# {'story_id': 52846, 'characters': {'Joyce': 'positive'}}
# {'story_id': 52843, 'characters': {'Jane': 'positive'}}
# {'story_id': 52844, 'characters': {'Jay': 'positive'}}
# {'story_id': 28885, 'characters': {'Jenny': 'positive'}}
# {'story_id': 28879, 'characters': {'Abe': 'positive'}}
# {'story_id': 52847, 'characters': {'Lester': 'positive'}}
# {'story_id': 28886, 'characters': {'Will': 'positive'}}
# {'story_id': 28887, 'characters': {'Olivia': 'positive'}}
# {'story_id': 28883, 'characters': {'Donna': 'positive', 'Jim': 'positive'}}
# {'story_id': 52859, 'characters': {'Fred': 'positive'}}
# {'story_id': 52848, 'characters': {'Jessica': 'positive'}}
# {'story_id': 52858, 'characters': {'Mike': 'positive'}}
# {'story_id': 28891, 'characters': {'Tim': 'positive'}}
# {'story_id': 28890, 'characters': {'Rhonda': 'negative'}}
# {'story_id': 52851, 'characters': {'i': 'positive'}}
# {'story_id': 28898, 'characters': {'Maria': 'positive'}}
# {'story_id': 52845, 'characters': {'James': 'positive'}}
# {'story_id': 52841, 'characters': {'i': 'positive'}}
# {'story_id': 28888, 'characters': {'Tom': 'positive', 'Bob': 'negative'}}
# {'story_id': 28884, 'characters': {'brother': 'positive', 'i': 'negative'}}
# {'story_id': 52852, 'characters': {'Bob': 'positive'}}
# {'story_id': 28900, 'characters': {'Tim': 'positive'}}
# {'story_id': 52850, 'characters': {'Julie': 'positive'}}
# {'story_id': 52855, 'characters': {'Dan': 'positive'}}
# {'story_id': 28901, 'characters': {'Suzy': 'positive'}}
# {'story_id': 52865, 'characters': {}}
# {'story_id': 52854, 'characters': {'Peter': 'positive'}}
# {'story_id': 52857, 'characters': {'Bob': 'positive'}}
# {'story_id': 52853, 'characters': {'Jennifer': 'negative'}}
# {'story_id': 28895, 'characters': {'i': 'positive'}}
# {'story_id': 52856, 'characters': {'Billy': 'positive'}}
# {'story_id': 28897, 'characters': {'Michelle': 'negative'}}
# {'story_id': 52860, 'characters': {'Gregory': 'positive'}}
# {'story_id': 28899, 'characters': {'Patrick': 'negative'}}
# {'story_id': 28906, 'characters': {'Tom': 'negative'}}
# {'story_id': 28894, 'characters': {'daughter': 'positive', 'i': 'positive'}}
# {'story_id': 28896, 'characters': {'Ken': 'positive', 'Tony': 'positive'}}
# {'story_id': 28893, 'characters': {'Tom': 'positive'}}
# {'story_id': 28904, 'characters': {}}
# {'story_id': 52861, 'characters': {'Joe': 'positive', 'Gina': 'positive'}}
# {'story_id': 28903, 'characters': {'Tim': 'positive'}}
# {'story_id': 28908, 'characters': {}}
# {'story_id': 28892, 'characters': {'Greta': 'positive', 'Robbie': 'positive'}}
# {'story_id': 52863, 'characters': {'librarian': 'positive'}}
# {'story_id': 52869, 'characters': {'Shawn': 'negative', 'Jane': 'negative'}}
# {'story_id': 52866, 'characters': {'Cheryl': 'negative'}}
# {'story_id': 28905, 'characters': {'Cindy': 'negative'}}
# {'story_id': 28915, 'characters': {'Suzy': 'positive'}}
# {'story_id': 52864, 'characters': {'Quinn': 'positive'}}
# {'story_id': 28909, 'characters': {'Ann': 'positive'}}
# {'story_id': 52867, 'characters': {'Bob': 'positive'}}
# {'story_id': 28913, 'characters': {'John': 'positive'}}
# {'story_id': 28902, 'characters': {'Tom': 'positive'}}
# {'story_id': 52862, 'characters': {'i': 'positive'}}
# {'story_id': 52874, 'characters': {'Ben': 'negative'}}
# {'story_id': 52868, 'characters': {'Dan': 'positive'}}
# {'story_id': 28910, 'characters': {'Ava': 'positive'}}
# {'story_id': 28914, 'characters': {'Jennifer': 'positive'}}
# {'story_id': 52875, 'characters': {'Gina': 'negative'}}
# {'story_id': 28920, 'characters': {}}
# {'story_id': 52879, 'characters': {}}
# {'story_id': 28912, 'characters': {'Scott': 'positive'}}
# {'story_id': 52872, 'characters': {'Tim': 'positive'}}
# {'story_id': 28917, 'characters': {'Kelley': 'positive'}}
# {'story_id': 28916, 'characters': {'Allie': 'negative'}}
# {'story_id': 52873, 'characters': {'Kim': 'positive'}}
# {'story_id': 28911, 'characters': {'Roger': 'positive'}}
# {'story_id': 52876, 'characters': {'i': 'positive'}}
# {'story_id': 52881, 'characters': {'Ellie': 'positive'}}
# {'story_id': 28919, 'characters': {'Kevin': 'negative'}}
# {'story_id': 52871, 'characters': {'Bob': 'positive'}}
# {'story_id': 52877, 'characters': {'friend': 'positive', 'i': 'positive'}}
# {'story_id': 28924, 'characters': {'Britt': 'negative'}}
# {'story_id': 52880, 'characters': {'Cara': 'positive'}}
# {'story_id': 52878, 'characters': {'Candice': 'positive'}}
# {'story_id': 52882, 'characters': {'Juan': 'positive'}}
# {'story_id': 52870, 'characters': {'Mary': 'positive', 'Gina': 'positive'}}
# {'story_id': 28918, 'characters': {'Kevin': 'positive'}}
# {'story_id': 28926, 'characters': {'Kayla': 'positive'}}
# {'story_id': 28929, 'characters': {'Ashley': 'positive'}}
# {'story_id': 52885, 'characters': {'Sal': 'positive'}}
# {'story_id': 28907, 'characters': {'Fred': 'positive', 'Carl': 'positive', 'Derek': 'positive'}}
# {'story_id': 52886, 'characters': {'Harry': 'positive'}}
# {'story_id': 28922, 'characters': {'Milton': 'positive'}}
# {'story_id': 28932, 'characters': {}}
# {'story_id': 28923, 'characters': {'Sophie': 'positive'}}
# {'story_id': 28921, 'characters': {'Earl': 'positive', 'Alice': 'positive'}}
# {'story_id': 52883, 'characters': {'Jim': 'positive', 'Tim': 'positive'}}
# {'story_id': 28935, 'characters': {'Tim': 'negative'}}
# {'story_id': 52888, 'characters': {'Sean': 'positive', 'Sara': 'positive'}}
# {'story_id': 28927, 'characters': {'Vince': 'positive'}}
# {'story_id': 52887, 'characters': {'John': 'positive'}}
# {'story_id': 28925, 'characters': {'Carol': 'positive'}}
# {'story_id': 52884, 'characters': {'i': 'positive'}}
# {'story_id': 28930, 'characters': {'Miguel': 'positive'}}
# {'story_id': 52889, 'characters': {'Rex': 'negative'}}
# {'story_id': 52891, 'characters': {'Tim': 'positive', 'Joe': 'positive'}}
# {'story_id': 28928, 'characters': {'friend': 'positive', 'i': 'positive'}}
# {'story_id': 28931, 'characters': {'David': 'positive'}}
# {'story_id': 28939, 'characters': {'Joe': 'positive'}}
# {'story_id': 52892, 'characters': {'Jenny': 'negative'}}
# {'story_id': 52896, 'characters': {'Rick': 'positive'}}
# {'story_id': 28945, 'characters': {'Kim': 'positive'}}
# {'story_id': 28933, 'characters': {'Matthew': 'positive'}}
# {'story_id': 28934, 'characters': {'Gina': 'positive'}}
# {'story_id': 52903, 'characters': {'David': 'positive'}}
# {'story_id': 52894, 'characters': {'Brandon': 'positive'}}
# {'story_id': 52895, 'characters': {'Kelsi': 'positive'}}
# {'story_id': 28936, 'characters': {'Jim': 'positive', 'John': 'positive'}}
# {'story_id': 52893, 'characters': {'Ed': 'positive', 'John': 'positive'}}
# {'story_id': 52898, 'characters': {'Amy': 'negative'}}
# {'story_id': 52901, 'characters': {'Carry': 'positive'}}
# {'story_id': 52890, 'characters': {'Judy': 'positive', 'Hal': 'positive'}}
# {'story_id': 52900, 'characters': {'Gina': 'negative'}}
# {'story_id': 28946, 'characters': {'Taylor': 'positive'}}
# {'story_id': 28942, 'characters': {'Julie': 'negative'}}
# {'story_id': 28944, 'characters': {}}
# {'story_id': 28941, 'characters': {'Tabitha': 'positive'}}
# {'story_id': 28938, 'characters': {'Jim': 'positive'}}
# {'story_id': 28943, 'characters': {'Tommy': 'positive'}}
# {'story_id': 28937, 'characters': {'Chance': 'positive', 'Sandra': 'negative'}}
# {'story_id': 28940, 'characters': {'Brian': 'positive'}}
# {'story_id': 52899, 'characters': {'Joe': 'positive'}}
# {'story_id': 28954, 'characters': {'Suzy': 'positive'}}
# {'story_id': 28947, 'characters': {'Tim': 'positive'}}
# {'story_id': 52897, 'characters': {'Ann': 'positive', 'Tori': 'positive', 'Anne': 'positive'}}
# {'story_id': 52902, 'characters': {'Samuel': 'positive', 'HG Wells': 'positive', 'Jules Verne': 'positive'}}
# {'story_id': 52904, 'characters': {"Tad Dunkin's": 'positive', 'Tad': 'positive'}}
# {'story_id': 28956, 'characters': {'Tom': 'positive'}}
# {'story_id': 28948, 'characters': {'Sarah': 'positive'}}
# {'story_id': 28950, 'characters': {'Sally': 'positive'}}
# {'story_id': 28951, 'characters': {'Reginald': 'positive'}}
# {'story_id': 52908, 'characters': {'Charles': 'positive'}}
# {'story_id': 28953, 'characters': {'Tim': 'negative'}}
# {'story_id': 52907, 'characters': {'i': 'positive'}}
# {'story_id': 28961, 'characters': {'Tim': 'positive'}}
# {'story_id': 52906, 'characters': {'i': 'positive'}}
# {'story_id': 52905, 'characters': {'Danny': 'positive', 'Paisley': 'positive'}}
# {'story_id': 28949, 'characters': {'Jill': 'positive'}}
# {'story_id': 28952, 'characters': {'Wendy': 'negative'}}
# {'story_id': 52911, 'characters': {'Tom': 'positive'}}
# {'story_id': 52909, 'characters': {'Kelly': 'negative'}}
# {'story_id': 52915, 'characters': {'Joe': 'positive', 'Jeb': 'positive'}}
# {'story_id': 28960, 'characters': {'John': 'positive'}}
# {'story_id': 28959, 'characters': {'Rosalyn': 'positive'}}
# {'story_id': 52916, 'characters': {'Gina': 'negative'}}
# {'story_id': 52912, 'characters': {'Connie': 'negative'}}
# {'story_id': 28957, 'characters': {'Brittany': 'positive'}}
# {'story_id': 52913, 'characters': {'Kurtis': 'positive'}}
# {'story_id': 52914, 'characters': {'Neil': 'positive'}}
# {'story_id': 28955, 'characters': {'Jimmy': 'positive'}}
# {'story_id': 52910, 'characters': {'Ava': 'negative'}}
# {'story_id': 52920, 'characters': {'father': 'positive'}}
# {'story_id': 52917, 'characters': {'Ann': 'positive'}}
# {'story_id': 28972, 'characters': {'Jenny': 'positive'}}
# {'story_id': 52918, 'characters': {'Kelly': 'positive'}}
# {'story_id': 28964, 'characters': {'Chesney': 'positive'}}
# {'story_id': 52919, 'characters': {'Rory': 'negative'}}
# {'story_id': 28971, 'characters': {'Andrea': 'positive'}}
# {'story_id': 52921, 'characters': {'Lynn': 'positive'}}
# {'story_id': 52924, 'characters': {}}
# {'story_id': 28958, 'characters': {'Leo': 'positive'}}
# {'story_id': 28966, 'characters': {'Rob': 'negative'}}
# {'story_id': 52922, 'characters': {'Tory': 'negative'}}
# {'story_id': 28970, 'characters': {'Sean': 'positive'}}
# {'story_id': 28965, 'characters': {'Joey': 'positive'}}
# {'story_id': 28962, 'characters': {'Anna': 'positive', 'Dale': 'positive'}}
# {'story_id': 52923, 'characters': {'i': 'positive'}}
# {'story_id': 28969, 'characters': {'Tommy': 'positive'}}
# {'story_id': 28967, 'characters': {'Joey': 'negative'}}
# {'story_id': 28979, 'characters': {'Tom': 'positive'}}
# {'story_id': 52925, 'characters': {'Cole': 'positive'}}
# {'story_id': 28973, 'characters': {'Megan': 'positive'}}
# {'story_id': 28963, 'characters': {'Mimi': 'negative', 'Al': 'negative'}}
# {'story_id': 52930, 'characters': {'Austin': 'positive'}}
# {'story_id': 52929, 'characters': {'Chelsea': 'positive'}}
# {'story_id': 28975, 'characters': {'Jane': 'positive'}}
# {'story_id': 28974, 'characters': {'June': 'positive'}}
# {'story_id': 52934, 'characters': {}}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 31
#      30         futures = {executor.submit(process_story, i, row, sentiment) for i, row in enumerate(reader)}
# ---> 31         stories = [future.result() for future in as_completed(futures)]
#      33 with open("val_dataset.json", "w") as outfile:
#
# Cell In[23], line 31, in <listcomp>(.0)
#      30         futures = {executor.submit(process_story, i, row, sentiment) for i, row in enumerate(reader)}
# ---> 31         stories = [future.result() for future in as_completed(futures)]
#      33 with open("val_dataset.json", "w") as outfile:
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/concurrent/futures/_base.py:244, in as_completed(fs, timeout)
#     240         raise TimeoutError(
#     241                 '%d (of %d) futures unfinished' % (
#     242                 len(pending), total_futures))
# --> 244 waiter.event.wait(wait_timeout)
#     246 with waiter.lock:
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/threading.py:558, in Event.wait(self, timeout)
#     557 if not signaled:
# --> 558     signaled = self._cond.wait(timeout)
#     559 return signaled
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     301 if timeout is None:
# --> 302     waiter.acquire()
#     303     gotit = True
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[23], line 31
#      29     with ThreadPoolExecutor() as executor:
#      30         futures = {executor.submit(process_story, i, row, sentiment) for i, row in enumerate(reader)}
# ---> 31         stories = [future.result() for future in as_completed(futures)]
#      33 with open("val_dataset.json", "w") as outfile:
#      34     json.dump(stories, outfile, indent=4)
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/concurrent/futures/_base.py:644, in Executor.__exit__(self, exc_type, exc_val, exc_tb)
#     643 def __exit__(self, exc_type, exc_val, exc_tb):
# --> 644     self.shutdown(wait=True)
#     645     return False
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/concurrent/futures/thread.py:236, in ThreadPoolExecutor.shutdown(self, wait)
#     234 if wait:
#     235     for t in self._threads:
# --> 236         t.join()
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/threading.py:1011, in Thread.join(self, timeout)
#    1008     raise RuntimeError("cannot join current thread")
#    1010 if timeout is None:
# -> 1011     self._wait_for_tstate_lock()
#    1012 else:
#    1013     # the behavior of a negative timeout isn't documented, but
#    1014     # historically .join(timeout=x) for x<0 has acted as if timeout=0
#    1015     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#
# File ~/anaconda3/envs/nlp-course-team-astley/lib/python3.8/threading.py:1027, in Thread._wait_for_tstate_lock(self, block, timeout)
#    1025 if lock is None:  # already determined that the C code is done
#    1026     assert self._is_stopped
# -> 1027 elif lock.acquire(block, timeout):
#    1028     lock.release()
#    1029     self._stop()
#
# KeyboardInterrupt:

# %%
with open("ROC_train_stories_context.json", 'r') as file_characters:
    data = json.load(file_characters)
    data.sort(key=lambda x: x['story_id'])
    with open("ROC_train_stories_context1.json", "w") as outfile:
        json.dump(data, outfile, indent=4)

# %%
with open("new_final.json", 'r') as file_characters:
    data = json.load(file_characters)
    for story in data:
        print(story)

# %%
with open("new_final.json", "r") as miss:
    to_add = json.load(miss)

with open("ROC_train_stories_context1.json", "r") as outfile:
    orig = json.load(outfile)

i = 0
for item in orig:
    i+=1


print(i)
# Out:
# 52665

# %%
with open("ROC_val_stories_context.json", 'r') as file_characters:
    data = json.load(file_characters)
    data.sort(key=lambda x: x['story_id'])
    with open("ROC_val_stories_context1.json", "w") as outfile:
        json.dump(data, outfile, indent=4)

# %%
moje = {}

with open("ROC_val_stories_context1.json", 'r') as file_characters:
    data = json.load(file_characters)
    for item in data:
        item['story_id'] = item['story_id'] + 52665


with open("ROC_val_stories_context2.json", "w") as outfile:
    json.dump(data, outfile, indent=4)
